# %% [markdown]
# ## Домашняя работа
#
# ###   f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30
# ###   f(x) = - 18x^3+5x^2 + 10x - 30
#
# | Задача | Результат |
# | ------ | ------ |
# | Определить корни | ✅ |
# | Найти интервалы, на которых функция возрастает | ✅ |
# | Найти интервалы, на которых функция убывает | ✅ |
# | Построить график | ✅ |
# | Вычислить вершину | ✅ |
# | Определить промежутки, на котором f > 0 | ✅ |
# | Определить промежутки, на котором f < 0 | ✅ |

# %%
from sympy import *

# %% [markdown]
# - Функция (f_x)

# %%
x = Symbol('x')
f_x = sympify('- 18*x^3 + 5*x^2 + 10*x - 30') #-12*x^4*sin(cos(x)) - 18*x^3 + 5*x^2 + 10*x - 30       8*x^3 -36*x^2 + 54*x -27
f_x
# Out:
# -18*x**3 + 5*x**2 + 10*x - 30

# %% [markdown]
# - Корни функции

# %%
roots = solve(f_x)
print(f'Корни:', roots)
# Out:
# Корни: [5/54 - 565/(972*(-1/2 - sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)) - (-1/2 - sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)/3, 5/54 - (-1/2 + sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)/3 - 565/(972*(-1/2 + sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)), -(5*sqrt(218931)/108 + 127045/5832)**(1/3)/3 - 565/(972*(5*sqrt(218931)/108 + 127045/5832)**(1/3)) + 5/54]

# %% [markdown]
# - График функции

# %%
chart_1 = plotting.plot(f_x, (x, -1, 1), line_color='red')

# %% [markdown]
# - Интервалы, на которых функция возрастает

# %%
print(solve(f_x > 0))
# Out:
# (-oo < x) & (x < CRootOf(18*x**3 - 5*x**2 - 10*x + 30, 0))

# %% [markdown]
# - Интервалы, на которых функция убывает

# %%
print(solve(f_x < 0))
# Out:
# (x < oo) & (CRootOf(18*x**3 - 5*x**2 - 10*x + 30, 0) < x)

# %% [markdown]
# <br/><br/><br/>
# - Производная функции (derivative_f_x)

# %%
derivative_f_x = f_x.diff(x)
derivative_f_x
# Out:
# -54*x**2 + 10*x + 10

# %% [markdown]
# - График производной функции

# %%
chart_2 = plotting.plot(derivative_f_x, (x, -0.5, 0.5), line_color='green')

# %% [markdown]
# - Вершина в точке

# %%
print(solve(derivative_f_x)[0].evalf())
# Out:
# -0.347587567555730

# %%
print(solve(derivative_f_x))
# Out:
# [5/54 - sqrt(565)/54, 5/54 + sqrt(565)/54]

# %% [markdown]
# - Интервалы, на которых производная функции возрастает

# %%
print(solve(derivative_f_x > 0))
# Out:
# (x < 5/54 + sqrt(565)/54) & (5/54 - sqrt(565)/54 < x)

# %% [markdown]
# - Интервалы, на которых производная функции убывает

# %%
print(solve(derivative_f_x < 0))
# Out:
# ((-oo < x) & (x < 5/54 - sqrt(565)/54)) | ((x < oo) & (5/54 + sqrt(565)/54 < x))
